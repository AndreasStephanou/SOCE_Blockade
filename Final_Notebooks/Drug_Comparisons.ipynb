# %%
import os
import pandas as pd
import scanpy as sc
import anndata as ad
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.spatial.distance import euclidean
from sklearn.metrics.pairwise import cosine_similarity

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=300, facecolor="white")
sc.set_figure_params(fontsize=6)
sc.settings.vector_friendly = False
# Out:
# scanpy==1.10.3 anndata==0.10.9 umap==0.5.7 numpy==2.0.2 scipy==1.13.1 pandas==2.2.3 scikit-learn==1.5.2 statsmodels==0.14.4 igraph==0.11.8 pynndescent==0.5.13

# %%
#Load Annotated Data
adata = sc.read_h5ad('Final_Objects/PBMCs_anno_manual_refined_renamed.h5ad')

# %%
# Create base Rep_ID column by concatenating ExperimentID and ConditionID
adata.obs['Rep_ID'] = adata.obs['ExperimentID'].astype(str) + "_" + adata.obs['ConditionID'].astype(str)

# Define function to parse Rep_ID and construct replicate names
def differentiate_replicates(df):
    df = df.copy()  # Avoid modifying in-place

    # Extract components
    df['Expt_Number'] = df['Rep_ID'].str.split('_').str[0]
    df['Mix_Number'] = df['Rep_ID'].str.split('_').str[1]
    
    # Ensure correct dtype
    df['Condition'] = df['Condition'].astype(str)
    df['Donor'] = df['Donor'].astype(str)

    # Create new replicate identifier
    df['Rep_ID'] = df['Donor'] + '_' + df['Condition'] + '_' + df['Mix_Number']
    
    return df

# Apply to adata.obs
adata.obs = differentiate_replicates(adata.obs)

# %%
# Dictionary mapping Mix labels to Replicate labels
replacement_dict = {
    'Mix1': 'Rep1',
    'Mix2': 'Rep2',
    'Mix3': 'Rep1',
    'Mix4': 'Rep2',
    'Mix5': 'Rep1',
    'Mix6': 'Rep2',
    'Mix7': 'Rep1',
    'Mix8': 'Rep2',
    # Add more as needed
}

# Function to replace Mix label at the end of Rep_ID
def replace_mix_ending(rep_id):
    for old, new in replacement_dict.items():
        if old in rep_id:
            return rep_id.replace(old, new)
    return rep_id  # If no match, return unchanged

# Apply the function
adata.obs['Rep_ID'] = adata.obs['Rep_ID'].apply(replace_mix_ending)

# %%
manual_order = ['Control',
   'BTP2',
    'CM4620',
    'PHA',
    'PHA + BTP2',
    'PHA + CM4620']

adata.obs['Condition'] = pd.Categorical(adata.obs['Condition'], categories=manual_order, ordered=True)

# %%
adata = adata.raw.to_adata()

# %%
raw = sc.read_h5ad("Final_Objects/PBMC_raw.h5ad")

# Ensure alignment of cells and genes
# This assumes that obs (cells) and var (genes) match between the two objects
raw = raw[adata.obs_names, adata.var_names]

# Add raw counts into the .raw slot of adata
adata.raw = raw
adata.layers['counts'] = adata.raw.X

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse import issparse
from adjustText import adjust_text

from pydeseq2.dds import DeseqDataSet, DefaultInference
from pydeseq2.ds import DeseqStats

sns.set(style="white")

CELLTYPE_COL   = "Broad_Manual_Anno_renamed"
CONDITION_COL  = "Condition"
SAMPLE_COL     = "sample"
MIN_CELLS_PER_PSEUDOBULK = 10
MIN_SAMPLES_PER_GROUP    = 2
LOGFC_THR = 1.0
PADJ_THR  = 0.01

cell_type_colors = {
    'B Cells': '#8dd3c7',
    'CD14+ Monocytes': '#74c476',
    'CD16+ Monocytes': '#bebada',
    'Dendritic Cells': '#fb8072',
    'CD8+ Effector T Cells': '#80b1d3',
    'CD8+ Naive T Cells': '#fdb462',
    'CD4+ T Cells': '#b3de69',
    'NK Cells': '#fccde5',
    'Plasma Cells': '#ae017e',
    'CD4+ Treg Cells': '#bc80bd'
}
cell_type_order = [
    'B Cells','CD14+ Monocytes','CD16+ Monocytes','Dendritic Cells','NK Cells',
    'CD8+ Effector T Cells','CD8+ Naive T Cells','CD4+ T Cells','CD4+ Treg Cells','Plasma Cells'
]
regulation_shapes = {'upregulated': 'o', 'downregulated': 's'}

def _get_counts_matrix(adata):
    return adata.layers['counts'] if 'counts' in adata.layers else adata.X  # cells × genes

def _pseudobulk_by_sample(adata_sub, min_cells=MIN_CELLS_PER_PSEUDOBULK):
    X = _get_counts_matrix(adata_sub)
    if issparse(X):
        X = X.tocsr()

    obs = adata_sub.obs[[SAMPLE_COL, CONDITION_COL]].copy()
    sample_sizes = obs.groupby(SAMPLE_COL).size()
    keep_samples = sample_sizes.index[sample_sizes >= min_cells].tolist()
    obs = obs[obs[SAMPLE_COL].isin(keep_samples)]
    if obs.empty:
        return None, None

    gene_names = adata_sub.var_names.to_list()
    sample_list = sorted(obs[SAMPLE_COL].unique())
    mat = np.zeros((len(gene_names), len(sample_list)), dtype=np.float64)

    # indexes in this sliced AnnData align: obs rows ? X rows
    for j, s in enumerate(sample_list):
        rows = np.where(obs[SAMPLE_COL].values == s)[0]
        col = X[rows, :].sum(axis=0)
        if issparse(col):
            col = col.A1
        mat[:, j] = col

    # return genes × samples (we?ll transpose for PyDESeq2)
    counts_df = pd.DataFrame(mat, index=gene_names, columns=sample_list)
    meta = (
        obs[[SAMPLE_COL, CONDITION_COL]]
        .drop_duplicates(subset=[SAMPLE_COL])
        .set_index(SAMPLE_COL)
        .loc[sample_list]
        .copy()
    )
    meta.index.name = "sample"
    meta.reset_index(inplace=True)
    return counts_df, meta

def _coef_and_flip(dds, condition_col, test, ref):
    cols = list(dds.varm["LFC"].columns)

    # Normalize: lowercase and keep only letters+numbers
    def norm(s):
        return "".join(ch for ch in str(s).lower() if ch.isalnum())

    want_test = norm(test)
    want_ref  = norm(ref)
    prefix = f"{condition_col}_".lower()

    # Look through available LFC columns (skip intercept)
    for c in cols:
        if c.lower() == "intercept":
            continue
        if not c.lower().startswith(prefix):
            continue
        try:
            # expected shape: Condition_<left>_vs_<right>
            tail = c[len(condition_col) + 1:]  # drop "Condition_"
            left, right = tail.split("_vs_")
        except Exception:
            continue

        left_n, right_n = norm(left), norm(right)
        if left_n == want_test and right_n == want_ref:
            return c, False        # direct: test vs ref
        if left_n == want_ref and right_n == want_test:
            return c, True         # reverse: ref vs test -> flip sign

    raise ValueError(
        f"Could not find coef for {condition_col}: wanted {test} vs {ref} (or reverse). "
        f"Got: {cols}"
)

def _volcano_plot(df_sig, condition1, condition2, out_png, logfc_thr=LOGFC_THR, padj_thr=PADJ_THR):
    df_sig = df_sig.copy()
    df_sig["pvals_adj"] = df_sig["pvals_adj"].clip(lower=1e-300)
    df_sig["-log10_pvals_adj"] = -np.log10(df_sig["pvals_adj"])

    plt.figure(figsize=(5, 3))
    sns.scatterplot(
        data=df_sig, x="log2fc_shrunk", y="-log10_pvals_adj",
        hue="Cell type",
        hue_order=[ct for ct in cell_type_order if ct in df_sig["Cell type"].unique()],
        style="Regulation", markers=regulation_shapes,
        palette=cell_type_colors, s=15
    )
    plt.axhline(y=-np.log10(padj_thr), linestyle="--", linewidth=0.5, color="red")
    plt.axvline(x=logfc_thr, linestyle="--", linewidth=0.5, color="blue")
    plt.axvline(x=-logfc_thr, linestyle="--", linewidth=0.5, color="blue")
    plt.xlabel("Shrunken log2 fold-change (apeglm)")
    plt.ylabel("-log10(adjusted p-value)")
    plt.title(f"DESeq2 (pseudobulk) per cell type: {condition1} vs {condition2}")
    plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", frameon=False)

    texts = []
    for regulation in ["upregulated", "downregulated"]:
        top = (df_sig[df_sig["Regulation"] == regulation]
               .sort_values("-log10_pvals_adj", ascending=False).head(5))
        for _, r in top.iterrows():
            texts.append(plt.text(r["log2fc_shrunk"], r["-log10_pvals_adj"], r["names"],
                                  fontsize=6, ha="right"))
    adjust_text(texts, arrowprops=dict(arrowstyle="->", color="gray", lw=1))
    plt.tight_layout()
    plt.savefig(out_png, dpi=300, bbox_inches="tight")
    plt.show()

def differential_expression_deseq2_pseudobulk(
    adata, condition1, condition2,
    logfc_threshold=LOGFC_THR, pval_adj_threshold=PADJ_THR,
    out_root="Figures/Drug_comparison_DESeq2"
):
    comp_tag = f"{condition1.replace(' ', '_')}_vs_{condition2.replace(' ', '_')}"
    out_dir = os.path.join(out_root, comp_tag)
    os.makedirs(out_dir, exist_ok=True)

    results_all = []
    for ct in adata.obs[CELLTYPE_COL].unique():
        ad_ct = adata[adata.obs[CELLTYPE_COL] == ct]
        ad_ct = ad_ct[ad_ct.obs[CONDITION_COL].isin([condition1, condition2])]

        counts_df, meta_df = _pseudobulk_by_sample(ad_ct)
        if counts_df is None:
            continue

        # keep only these two conditions and check replicates
        use = meta_df[meta_df[CONDITION_COL].isin([condition1, condition2])].copy()
        use = use.set_index("sample")
        n1 = (use[CONDITION_COL] == condition1).sum()
        n2 = (use[CONDITION_COL] == condition2).sum()
        if n1 < MIN_SAMPLES_PER_GROUP or n2 < MIN_SAMPLES_PER_GROUP:
            continue

        # Ensure integer counts for DESeq2
        counts_use = counts_df.loc[:, use.index].T.astype(int)  # samples × genes
        
        # 1) Build and fit the DESeq2 dataset
        dds = DeseqDataSet(
            counts=counts_use,                     # samples × genes (ints)
            metadata=use[[CONDITION_COL]],         # DataFrame with the Condition column
            design_factors=CONDITION_COL,          
            refit_cooks=True,
        )
        dds.deseq2()
        inference = DefaultInference(n_cpus=8)

        # 2) Stats with correct signature (TEST vs REF)
        ds = DeseqStats(
            dds,
            contrast=[CONDITION_COL, condition1, condition2],
            inference=inference,  
            independent_filter=True,
        )
        ds.summary()
        
        # 3) Shrink the correct coefficient
        coeff, flip = _coef_and_flip(dds, CONDITION_COL, condition1, condition2)
        ds.lfc_shrink(coeff=coeff)
        
        res = ds.results_df.copy()
        if flip:
            # PyDESeq2 writes shrunk values into 'log2FoldChange'; flip to get TEST/REF
            res["log2FoldChange"] = -res["log2FoldChange"]
        
        res["names"] = res.index.astype(str)
        res.rename(columns={"log2FoldChange": "log2fc_shrunk",
                            "pvalue": "pval", "padj": "pvals_adj"}, inplace=True)
        res["Cell type"] = ct
        results_all.append(res)

    if not results_all:
        print(f"[WARN] No valid DESeq2 results for {comp_tag} (check replicates/cell counts).")
        return

    de_results_combined = pd.concat(results_all, ignore_index=True)
    de_results_combined["Regulation"] = "not_significant"
    up = (de_results_combined["log2fc_shrunk"] >= logfc_threshold) & (de_results_combined["pvals_adj"] < pval_adj_threshold)
    dn = (de_results_combined["log2fc_shrunk"] <= -logfc_threshold) & (de_results_combined["pvals_adj"] < pval_adj_threshold)
    de_results_combined.loc[up, "Regulation"] = "upregulated"
    de_results_combined.loc[dn, "Regulation"] = "downregulated"

    # Save combined + significant tables
    out_csv_all = os.path.join(out_dir, f"DESeq2_allgenes_{comp_tag}.csv")
    de_results_combined.to_csv(out_csv_all, index=False)

    sig = de_results_combined[de_results_combined["Regulation"] != "not_significant"].copy()
    out_csv_sig = os.path.join(out_dir, f"DESeq2_significant_{comp_tag}.csv")
    sig.to_csv(out_csv_sig, index=False)

    # Volcano using shrunken LFCs
    if not sig.empty:
        out_png = os.path.join(out_dir, f"DESeq2_volcano_{comp_tag}.pdf")
        _volcano_plot(sig, condition1, condition2, out_png,
                      logfc_thr=logfc_threshold, padj_thr=pval_adj_threshold)

# %%
condition_pairs = [
    ('BTP2', 'Control'),
    ('CM4620', 'Control'),
    ('BTP2', 'CM4620'),
    ('PHA', 'Control'),
    ('PHA + BTP2', 'PHA'),
    ('PHA + CM4620', 'PHA'),
    ('PHA + BTP2', 'PHA + CM4620'),
]

for c1, c2 in condition_pairs:
    differential_expression_deseq2_pseudobulk(adata, c1, c2)
# Out:
# Fitting size factors...
# ... done in 0.01 seconds.
#
# Fitting dispersions...
# ... done in 3.69 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.38 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.86 seconds.
#
# Fitting LFCs...
# ... done in 3.13 seconds.
#
# Calculating cook's distance...
# ... done in 0.02 seconds.
#
# Replacing 0 outlier genes.
#
# Running Wald tests...
# ... done in 15.97 seconds.
#
# Fitting MAP LFCs...
# Log2 fold change & Wald test p-value: Condition PHA + BTP2 vs PHA
#             baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# A1BG      229.541283        0.641917  0.230608   2.783583  5.376218e-03
# A1BG-AS1   39.914813        0.152209  0.330432   0.460636  6.450596e-01
# A2M         1.381362        2.389296  1.468897   1.626592  1.038239e-01
# A2M-AS1     4.862601        2.707317  0.776088   3.488414  4.858943e-04
# A4GALT      0.901328       -0.397522  2.478202  -0.160408  8.725600e-01
# ...

# %%
# Volcano from saved significant-gene CSVs (one plot per CSV)

import os, re, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
try:
    from adjustText import adjust_text
    _HAS_ADJUSTTEXT = True
except Exception:
    _HAS_ADJUSTTEXT = False

sns.set(style="white")

# ---- Styling you used before ----
cell_type_colors = {
    'B Cells': '#8dd3c7',
    'CD14+ Monocytes': '#74c476',
    'CD16+ Monocytes': '#bebada',
    'Dendritic Cells': '#fb8072',
    'CD8+ Effector T Cells': '#80b1d3',
    'CD8+ Naive T Cells': '#fdb462',
    'CD4+ T Cells': '#b3de69',
    'NK Cells': '#fccde5',
    'Plasma Cells': '#ae017e',
    'CD4+ Treg Cells': '#bc80bd'
}
cell_type_order = [
    'B Cells','CD14+ Monocytes','CD16+ Monocytes','Dendritic Cells','NK Cells',
    'CD8+ Effector T Cells','CD8+ Naive T Cells','CD4+ T Cells','CD4+ Treg Cells','Plasma Cells'
]
regulation_shapes = {'upregulated': 'o', 'downregulated': 's'}

# ---- Helpers ----
def _normalize_columns(df):
    """Return a copy with standardized columns: names, log2fc_shrunk, pvals_adj, Cell type, Regulation."""
    d = df.copy()

    # gene name
    if 'names' not in d.columns:
        if 'Gene' in d.columns:
            d = d.rename(columns={'Gene': 'names'})
        elif 'gene' in d.columns:
            d = d.rename(columns={'gene': 'names'})

    # logFC
    if 'log2fc_shrunk' not in d.columns:
        if 'log2FoldChange' in d.columns:
            d = d.rename(columns={'log2FoldChange': 'log2fc_shrunk'})
        elif 'logfoldchanges' in d.columns:
            d = d.rename(columns={'logfoldchanges': 'log2fc_shrunk'})
        elif 'LogFC' in d.columns:
            d = d.rename(columns={'LogFC': 'log2fc_shrunk'})

    # adjusted p
    if 'pvals_adj' not in d.columns:
        if 'padj' in d.columns:
            d = d.rename(columns={'padj': 'pvals_adj'})
        elif 'Adjusted_PValue' in d.columns:
            d = d.rename(columns={'Adjusted_PValue': 'pvals_adj'})

    # cell type
    if 'Cell type' not in d.columns and 'Celltype' in d.columns:
        d = d.rename(columns={'Celltype': 'Cell type'})

    # regulation
    if 'Regulation' not in d.columns:
        # if missing, compute a default classification (conservative)
        # you can tweak thresholds here or pass them down if you prefer
        LOGFC_THR = 1.0
        PADJ_THR = 0.01
        d['Regulation'] = 'not_significant'
        d.loc[(d['log2fc_shrunk'] >= LOGFC_THR) & (d['pvals_adj'] < PADJ_THR), 'Regulation'] = 'upregulated'
        d.loc[(d['log2fc_shrunk'] <= -LOGFC_THR) & (d['pvals_adj'] < PADJ_THR), 'Regulation'] = 'downregulated'

    # ensure required columns exist
    req = ['names', 'log2fc_shrunk', 'pvals_adj', 'Regulation']
    missing = [c for c in req if c not in d.columns]
    if missing:
        raise ValueError(f"CSV is missing required columns after normalization: {missing}")

    return d

def _parse_comparison_from_filename(path):
    """
    Parse 'X_vs_Y' from file name; convert underscores to spaces so 'PHA_+_BTP2' -> 'PHA + BTP2'.
    Works with names like DESeq2_significant_BTP2_vs_Control.csv
    """
    base = os.path.basename(path)
    stem = os.path.splitext(base)[0]
    # find the last '_vs_' occurrence to be safe
    i = stem.rfind('_vs_')
    if i != -1:
        left = stem[:i].split('DESeq2_significant_')[-1]
        right = stem[i+4:]
        left = left.replace('_', ' ')
        right = right.replace('_', ' ')
        return f"{left} vs {right}"
    # fallback: just use stem
    return stem.replace('_', ' ')

def make_volcano_from_csv(
    csv_path,
    out_dir=None,
    pval_adj_threshold=0.01,
    logfc_threshold=1.0,
    max_labels_per_side=5
):
    df = pd.read_csv(csv_path)
    df = _normalize_columns(df)

    # If the file already contains only significant genes, keep going; otherwise filter here:
    sig = df.copy()

    # clip p to avoid log10(0)
    sig['pvals_adj'] = sig['pvals_adj'].clip(lower=1e-300)
    sig['-log10_pvals_adj'] = -np.log10(sig['pvals_adj'])

    title = _parse_comparison_from_filename(csv_path)

    plt.figure(figsize=(2.5, 2))
    # hue by cell type if present; else a single color
    if 'Cell type' in sig.columns:
        hue_order = [ct for ct in cell_type_order if ct in sig['Cell type'].unique()]
        sns.scatterplot(
            data=sig,
            x='log2fc_shrunk', y='-log10_pvals_adj',
            hue='Cell type',
            hue_order=hue_order if len(hue_order) else None,
            style='Regulation' if 'Regulation' in sig.columns else None,
            markers=regulation_shapes if 'Regulation' in sig.columns else None,
            palette=cell_type_colors,
            s=15,legend=False
        )
        # plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', frameon=False)

    else:
        sns.scatterplot(data=sig, x='log2fc_shrunk', y='-log10_pvals_adj', s=15,legend=False)

    plt.axhline(y=-np.log10(pval_adj_threshold), color='red', linestyle='--', linewidth=0.5)
    plt.axvline(x=logfc_threshold, color='blue', linestyle='--', linewidth=0.5)
    plt.axvline(x=-logfc_threshold, color='blue', linestyle='--', linewidth=0.5)
    plt.xlabel('Shrunken log2FC')
    plt.ylabel('-log10(adj p-value)')
    plt.title(title)

    # Label top genes per side (if Regulation present)
    texts = []
    if 'Regulation' in sig.columns and _HAS_ADJUSTTEXT:
        for side in ['upregulated', 'downregulated']:
            top = (sig[sig['Regulation'] == side]
                   .sort_values('-log10_pvals_adj', ascending=False)
                   .head(max_labels_per_side))
            for _, r in top.iterrows():
                texts.append(plt.text(r['log2fc_shrunk'], r['-log10_pvals_adj'],
                                      r['names'], fontsize=6, ha='right'))
        adjust_text(texts, arrowprops=dict(arrowstyle='-', color='gray', lw=1))
    elif 'Regulation' in sig.columns and not _HAS_ADJUSTTEXT:
        # fallback simple labeling of the single top per side
        for side in ['upregulated', 'downregulated']:
            top = (sig[sig['Regulation'] == side]
                   .sort_values('-log10_pvals_adj', ascending=False)
                   .head(1))
            for _, r in top.iterrows():
                plt.text(r['log2fc_shrunk'], r['-log10_pvals_adj'],
                         r['names'], fontsize=6, ha='right')

    plt.tick_params(axis='x', which='both', bottom=True, top=False, length=3, color='black')
    plt.tick_params(axis='y', which='both', left=True, right=False, length=3, color='black')
    plt.tight_layout()

    if out_dir is None:
        out_dir = os.path.dirname(csv_path)
    os.makedirs(out_dir, exist_ok=True)

    out_stem = os.path.splitext(os.path.basename(csv_path))[0]
    out_path = os.path.join(out_dir, f"{out_stem}_volcano.pdf")
    plt.savefig(out_path, dpi=300, bbox_inches='tight')
    plt.show()
    print(f"[saved] {out_path}")

# ---- Example: point to your DESeq2 significant CSVs and batch plot ----
# For DESeq2 path structure like:
# Figures/Drug_comparison_DESeq2/<comp_tag>/DESeq2_significant_<comp_tag>.csv
root = "Figures/Drug_comparison_DESeq2"
csv_files = glob.glob(os.path.join(root, "**", "DESeq2_significant_*_vs_*.csv"), recursive=True)

plt.rcParams.update({
    "font.size": 6,        # base font
    "axes.titlesize": 6,
    "axes.labelsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "legend.fontsize": 6
})

for csv_path in sorted(csv_files):
    make_volcano_from_csv(
        csv_path,
        out_dir=None,              
        pval_adj_threshold=0.01,
        logfc_threshold=1,
        max_labels_per_side=5
    )
# Out:
# /tmp/ipykernel_1344810/2982867894.py:126: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# [saved] Figures/Drug_comparison_DESeq2/BTP2_vs_CM4620/DESeq2_significant_BTP2_vs_CM4620_volcano.pdf
# [saved] Figures/Drug_comparison_DESeq2/BTP2_vs_Control/DESeq2_significant_BTP2_vs_Control_volcano.pdf
# [saved] Figures/Drug_comparison_DESeq2/CM4620_vs_Control/DESeq2_significant_CM4620_vs_Control_volcano.pdf
# [saved] Figures/Drug_comparison_DESeq2/PHA_+_BTP2_vs_PHA/DESeq2_significant_PHA_+_BTP2_vs_PHA_volcano.pdf
# /tmp/ipykernel_1344810/2982867894.py:126: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# [saved] Figures/Drug_comparison_DESeq2/PHA_+_BTP2_vs_PHA_+_CM4620/DESeq2_significant_PHA_+_BTP2_vs_PHA_+_CM4620_volcano.pdf
# [saved] Figures/Drug_comparison_DESeq2/PHA_+_CM4620_vs_PHA/DESeq2_significant_PHA_+_CM4620_vs_PHA_volcano.pdf
# ...

# %%
# # Perform DGE for each cell type between two condition pairs
# from adjustText import adjust_text
# sns.set(style="white")
# sc.set_figure_params(fontsize=6)

# def differential_expression(adata, condition1, condition2, logfc_threshold=1.0, pval_adj_threshold=0.01):
#     differential_expression_results = []
#     cell_types = adata.obs['Broad_Manual_Anno_renamed'].unique()
    
#     # Define a consistent color for each cell type
#     cell_type_colors = {
#         'B Cells': '#8dd3c7',
#         'CD14+ Monocytes': '#74c476',
#         'CD16+ Monocytes': '#bebada',
#         'Dendritic Cells': '#fb8072',
#         'CD8+ Effector T Cells': '#80b1d3',
#         'CD8+ Naive T Cells': '#fdb462',
#         'CD4+ T Cells': '#b3de69',
#         'NK Cells': '#fccde5',
#         'Plasma Cells': '#ae017e',
#         'CD4+ Treg Cells': '#bc80bd'
#     }
#     # Define the order for cell types in the legend
#     cell_type_order = [
#         'B Cells',
#         'CD14+ Monocytes',
#         'CD16+ Monocytes',
#         'Dendritic Cells',
#         'NK Cells',
#         'CD8+ Effector T Cells',
#         'CD8+ Naive T Cells',
#         'CD4+ T Cells',
#         'CD4+ Treg Cells',
#         'Plasma Cells'
#     ]

#     # Define shapes for regulation types
#     regulation_shapes = {
#         'upregulated': 'o',  # Circle
#         'downregulated': 's' # Square
#     }
    
#     for cell_type in cell_types:
#         adata_sub = adata[adata.obs['Broad_Manual_Anno_renamed'] == cell_type]
#         adata_sub = adata_sub[adata_sub.obs['Condition'].isin([condition1, condition2])]
        
#         sc.tl.rank_genes_groups(adata_sub, groupby='Condition', groups=[condition1], reference=condition2, method='wilcoxon')
        
#         de_result = sc.get.rank_genes_groups_df(adata_sub, group=condition1)
#         de_result['Cell type'] = cell_type
#         differential_expression_results.append(de_result)
    
#     de_results_combined = pd.concat(differential_expression_results, ignore_index=True)
    
#     de_results_combined['Regulation'] = 'not_significant'
#     de_results_combined.loc[(de_results_combined['logfoldchanges'] >= logfc_threshold) & (de_results_combined['pvals_adj'] < pval_adj_threshold), 'Regulation'] = 'upregulated'
#     de_results_combined.loc[(de_results_combined['logfoldchanges'] <= -logfc_threshold) & (de_results_combined['pvals_adj'] < pval_adj_threshold), 'Regulation'] = 'downregulated'
    
#     significant_genes = de_results_combined[de_results_combined['Regulation'] != 'not_significant']
    
#     # Define a small epsilon to avoid log of zero
#     epsilon = 1e-300  # A very small value, smaller than typical p-value precision
#     significant_genes.loc[:, 'pvals_adj'] = significant_genes['pvals_adj'].clip(lower=epsilon)

#     filename = f"Final_Notebooks/Figures/Drug_comparison/significant_genes_{condition1.replace(' ', '_')}_vs_{condition2.replace(' ', '_')}.csv"
#     significant_genes.to_csv(filename, index=False)
    
#     significant_genes.loc[:, '-log10_pvals_adj'] = -np.log10(significant_genes['pvals_adj'])
    
#     plt.figure(figsize=(4, 2))
#     sns.scatterplot(
#         data=significant_genes, 
#         x='logfoldchanges', 
#         y='-log10_pvals_adj', 
#         hue='Cell type', 
#         hue_order=cell_type_order,
#         style='Regulation', 
#         markers=regulation_shapes, 
#         palette=cell_type_colors,s=15
#     )
#     plt.axhline(y=-np.log10(pval_adj_threshold), color='red', linestyle='--',linewidth=0.5)
#     plt.axvline(x=logfc_threshold, color='blue', linestyle='--',linewidth=0.5)
#     plt.axvline(x=-logfc_threshold, color='blue', linestyle='--',linewidth=0.5)
#     plt.xlabel('Log Fold Change')
#     plt.ylabel('-log10(Adjusted p-value)')
#     plt.title(f'DGE per Cell Type for {condition2} vs {condition1}')
#     plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', frameon=False)

#     # Prepare text labels for adjustment
#     texts = []
#     for regulation in ['upregulated', 'downregulated']:
#         top_genes = significant_genes[significant_genes['Regulation'] == regulation]
#         top_genes = top_genes.sort_values(by='-log10_pvals_adj', ascending=False).head(5)
#         for _, row in top_genes.iterrows():
#             texts.append(plt.text(row['logfoldchanges'], row['-log10_pvals_adj'], 
#                                   row['names'], fontsize=6, ha='right'))

#     # Adjust text to avoid overlaps
#     adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray', lw=1))
#     plt.tick_params(axis='x', which='both', bottom=True, top=False, length=3, color='black')
#     plt.tick_params(axis='y', which='both', left=True, right=False, length=3, color='black')
#     plt.tight_layout()
    
#     filename_png = f"Final_Notebooks/Figures/Drug_comparison/significant_genes_{condition2.replace(' ', '_')}_vs_{condition1.replace(' ', '_')}_labeled.pdf"
#     plt.savefig(filename_png, dpi=300, bbox_inches='tight')
    
#     plt.show()

# # Example condition pairs
# condition_pairs = [
#     ('BTP2', 'Control'), 
#     ('CM4620', 'Control'), 
#     ('BTP2', 'CM4620'), 
#     ('PHA', 'Control'), 
#     ('PHA + BTP2', 'Control'), 
#     ('PHA + CM4620', 'Control'), 
#     ('PHA + BTP2', 'PHA'), 
#     ('PHA + CM4620', 'PHA'), 
#     ('PHA + BTP2', 'PHA + CM4620'),
#     # Add more pairs as needed
# ]

# # Run the differential expression analysis for each condition pair
# for condition1, condition2 in condition_pairs:
#     differential_expression(adata, condition1, condition2)

# %%
#Check for the number of cells in a given condition separated cell type
for i in adata.obs['Broad_Manual_Anno_renamed'].unique():
    print(pd.pivot_table(adata[adata.obs['Broad_Manual_Anno_renamed']==i].obs, index='Condition', columns='Donor', aggfunc='size', fill_value=0))
# Out:
# Donor         Donor1  Donor2  Donor3  Donor4
# Condition
# Control         1399    1629    2367    1455
# BTP2            1240    1640    1127    1501
# CM4620          1237    1568    1901    1461
# PHA              699    1995    1458    1132
# PHA + BTP2       757    2010    1422    1459
# PHA + CM4620     899    2274    1447    1323
# Donor         Donor1  Donor2  Donor3  Donor4
# Condition
# Control          511     792     930     772
# BTP2             454     797     495    1068
# CM4620           424     848     784     962
# PHA              289     877     450     625
# PHA + BTP2       333     672     456     683
# PHA + CM4620     390     796     467     658
# Donor         Donor1  Donor2  Donor3  Donor4
# Condition
# Control          298    1066    1180     466
# BTP2             268    1029     538     489
# CM4620           252    1043     971     461
# PHA              128    1103     590     376
# PHA + BTP2       146    1223     734     489
# ...

# %%
cell_type_colors = {
    'B Cells': '#8dd3c7',
    'CD14+ Monocytes': '#74c476',
    'CD16+ Monocytes': '#bebada',
    'Dendritic Cells': '#fb8072',
    'NK Cells': '#fccde5',
    'CD8+ Effector T Cells': '#80b1d3',
    'CD8+ Naive T Cells': '#fdb462',
    'CD4+ T Cells': '#b3de69',
    'CD4+ Treg Cells': '#bc80bd',
    'Plasma Cells': '#ae017e'
}

cell_type_order = ['B Cells',
    'CD14+ Monocytes',
    'CD16+ Monocytes',
    'Dendritic Cells',
    'NK Cells',
    'CD8+ Effector T Cells',
    'CD8+ Naive T Cells',
    'CD4+ T Cells',
    'CD4+ Treg Cells']

# %%
# Dot plot of DGE per cell type FROM PRE-SAVED CSVs (no Scanpy re-run)

import os, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
try:
    from adjustText import adjust_text
    _HAS_ADJUSTTEXT = True
except Exception:
    _HAS_ADJUSTTEXT = False

sns.set(style="white")

# --- your palette & order (Plasma Cells excluded later) ---
cell_type_colors = {
    'B Cells': '#8dd3c7',
    'CD14+ Monocytes': '#74c476',
    'CD16+ Monocytes': '#bebada',
    'Dendritic Cells': '#fb8072',
    'CD8+ Effector T Cells': '#80b1d3',
    'CD8+ Naive T Cells': '#fdb462',
    'CD4+ T Cells': '#b3de69',
    'NK Cells': '#fccde5',
    'Plasma Cells': '#ae017e',
    'CD4+ Treg Cells': '#bc80bd'
}
cell_type_order = [
    'B Cells','CD14+ Monocytes','CD16+ Monocytes','Dendritic Cells','NK Cells',
    'CD8+ Effector T Cells','CD8+ Naive T Cells','CD4+ T Cells','CD4+ Treg Cells','Plasma Cells'
]

# ---------- helpers ----------
def _normalize_columns(df):
    """Standardize to names, logFC_plot, pvals_adj, Cell type, Regulation."""
    d = df.copy()

    # gene name
    if 'names' not in d.columns:
        for c in ['Gene','gene','symbol','Symbol','Name','name']:
            if c in d.columns:
                d = d.rename(columns={c:'names'})
                break

    # logFC (prefer shrunken if present)
    if 'log2fc_shrunk' in d.columns:
        d = d.rename(columns={'log2fc_shrunk':'logFC_plot'})
    elif 'log2FoldChange' in d.columns:
        d = d.rename(columns={'log2FoldChange':'logFC_plot'})
    elif 'logfoldchanges' in d.columns:
        d = d.rename(columns={'logfoldchanges':'logFC_plot'})
    elif 'LogFC' in d.columns:
        d = d.rename(columns={'LogFC':'logFC_plot'})

    # adjusted p
    if 'pvals_adj' not in d.columns:
        for c in ['padj','Adjusted_PValue','qvalue','q_value']:
            if c in d.columns:
                d = d.rename(columns={c:'pvals_adj'})
                break

    # cell type column name
    if 'Cell type' not in d.columns and 'Celltype' in d.columns:
        d = d.rename(columns={'Celltype':'Cell type'})

    # require essentials
    need = ['names','logFC_plot','pvals_adj']
    missing = [c for c in need if c not in d.columns]
    if missing:
        raise ValueError(f"CSV missing required columns after normalization: {missing}")

    # clip p for log safety if needed downstream
    d['pvals_adj'] = pd.to_numeric(d['pvals_adj'], errors='coerce')
    return d

def _find_sig_csv(condition1, condition2):
    """Try DESeq2 path first; fallback to Wilcoxon path; also try reversed order."""
    def tag(a,b): return f"{a.replace(' ','_')}_vs_{b.replace(' ','_')}"
    candidates = []
    # DESeq2 first
    candidates.append(os.path.join(
        "Figures/Drug_comparison_DESeq2",
        tag(condition1, condition2),
        f"DESeq2_significant_{tag(condition1, condition2)}.csv"
    ))
    candidates.append(os.path.join(
        "Figures/Drug_comparison_DESeq2",
        tag(condition2, condition1),
        f"DESeq2_significant_{tag(condition2, condition1)}.csv"
    ))

    for p in candidates:
        if os.path.exists(p):
            return p
    raise FileNotFoundError(f"No CSV found for {condition1} vs {condition2}. Tried:\n" + "\n".join(candidates))

# ---------- main ----------
def violin_dotplot_dge_labeled_per_cell_type_from_csv(
    condition1, condition2,
    logfc_threshold=1.0,
    pval_adj_threshold=0.01,
    figsize=(4.5, 2.5)
):
    csv_path = _find_sig_csv(condition1, condition2)
    df = pd.read_csv(csv_path)
    df = _normalize_columns(df)

    # If 'Regulation' is missing in older files, compute it
    if 'Regulation' not in df.columns:
        df['Regulation'] = 'not_significant'
        df.loc[(df['logFC_plot'] >=  logfc_threshold) & (df['pvals_adj'] < pval_adj_threshold), 'Regulation'] = 'upregulated'
        df.loc[(df['logFC_plot'] <= -logfc_threshold) & (df['pvals_adj'] < pval_adj_threshold), 'Regulation'] = 'downregulated'

    # Keep only significant calls and desired cell types (exclude Plasma Cells)
    keep_order = [ct for ct in cell_type_order if ct != 'Plasma Cells']
    df = df[df['Regulation'] != 'not_significant']
    if 'Cell type' in df.columns:
        df = df[df['Cell type'].isin(keep_order)]
    else:
        # if no cell type column present, bail (plot needs x by cell type)
        raise ValueError("CSV lacks 'Cell type' column required for per-cell-type dot plot.")

    if df.empty:
        print(f"[warn] No significant genes to plot for {condition1} vs {condition2}.")
        return

    # Fixed figure
    fig, ax = plt.subplots(figsize=figsize)

    # Dot plot
    ax = sns.stripplot(
        x='Cell type',
        y='logFC_plot',
        data=df,
        hue='Cell type',
        order=keep_order,
        palette=cell_type_colors,
        dodge=0.5,
        jitter=0.7,
        size=2,
        alpha=0.7,
        ax=ax
    )
    # remove any legend if created
    leg = ax.get_legend()
    if leg is not None:
        leg.remove()

    # Build numeric x positions for label placement
    xpos = {ct: i for i, ct in enumerate(keep_order)}

    # Label top 3 up & down per cell type by logFC magnitude (as in your version)
    texts = []
    for ct in keep_order:
        sub = df[df['Cell type'] == ct]
        if sub.empty:
            continue
        top_up = sub[sub['Regulation'] == 'upregulated'].nlargest(3, 'logFC_plot')
        top_dn = sub[sub['Regulation'] == 'downregulated'].nsmallest(3, 'logFC_plot')
        top = pd.concat([top_up, top_dn], ignore_index=True)
        for _, r in top.iterrows():
            texts.append(ax.text(
                xpos[ct], r['logFC_plot'],
                r['names'], fontsize=4.5, ha='right', va='center', clip_on=True
            ))

    if _HAS_ADJUSTTEXT and texts:
        adjust_text(texts, ax=ax)

    # Cosmetics
    ax.axhline(0, color='black', linestyle='--', linewidth=1)
    ax.set_title(f"DGE Dot Plot: {condition2} vs {condition1}", fontsize=6)
    ax.set_ylabel("Log Fold Change", fontsize=6)
    ax.set_xlabel("")
    ax.grid(False)
    ax.set_xticklabels([])  # hide x tick labels as in your original
    ax.tick_params(axis='y', which='both', left=True, right=False, length=3, color='black', labelsize=6)

    # Save next to the CSV
    out_pdf = os.path.join(os.path.dirname(csv_path),
                           f"DGE_violin_dotplot_labeled_per_cell_type_{condition2.replace(' ','_')}_vs_{condition1.replace(' ','_')}.pdf")
    fig.savefig(out_pdf, dpi=300, bbox_inches='tight')
    plt.close(fig)
    print(f"[saved] {out_pdf}")

# ----------------- run it for your pairs -----------------
condition_pairs = [
    ('PHA', 'Control'),
    ('PHA + BTP2', 'PHA'),
    ('PHA + CM4620', 'PHA'),
]
for c1, c2 in condition_pairs:
    violin_dotplot_dge_labeled_per_cell_type_from_csv(c1, c2)
# Out:
# [saved] Figures/Drug_comparison_DESeq2/PHA_vs_Control/DGE_violin_dotplot_labeled_per_cell_type_Control_vs_PHA.pdf
# [saved] Figures/Drug_comparison_DESeq2/PHA_+_BTP2_vs_PHA/DGE_violin_dotplot_labeled_per_cell_type_PHA_vs_PHA_+_BTP2.pdf
# [saved] Figures/Drug_comparison_DESeq2/PHA_+_CM4620_vs_PHA/DGE_violin_dotplot_labeled_per_cell_type_PHA_vs_PHA_+_CM4620.pdf

# %%
#Dot plot of DGE for the condition pair of interest per each celltype
sns.set(style="white")
sc.set_figure_params(fontsize=6)

def violin_dotplot_dge_labeled_per_cell_type(adata, condition1, condition2, logfc_threshold=1.0, pval_adj_threshold=0.01):
    # Define the desired order of cell types and exclude 'Plasma Cells'
    differential_expression_results = []

    # Perform differential expression for each cell type and concatenate results
    for cell_type in cell_type_order:
        if cell_type == 'Plasma Cells':  # Exclude 'Plasma Cells'
            continue
        if cell_type in adata.obs['Broad_Manual_Anno_renamed'].unique():
            adata_sub = adata[adata.obs['Broad_Manual_Anno_renamed'] == cell_type]
            adata_sub = adata_sub[adata_sub.obs['Condition'].isin([condition1, condition2])]

            sc.tl.rank_genes_groups(adata_sub, groupby='Condition', groups=[condition1], reference=condition2, method='wilcoxon')

            de_result = sc.get.rank_genes_groups_df(adata_sub, group=condition1)
            de_result['Cell type'] = cell_type

            de_result['Regulation'] = 'not_significant'
            de_result.loc[(de_result['logfoldchanges'] >= logfc_threshold) & (de_result['pvals_adj'] < pval_adj_threshold), 'Regulation'] = 'upregulated'
            de_result.loc[(de_result['logfoldchanges'] <= -logfc_threshold) & (de_result['pvals_adj'] < pval_adj_threshold), 'Regulation'] = 'downregulated'

            # Filter for significant genes only
            significant_genes = de_result[de_result['Regulation'] != 'not_significant']
            differential_expression_results.append(significant_genes)

    # Combine results for all cell types into a single dataframe
    de_results_combined = pd.concat(differential_expression_results, ignore_index=True)

    if not de_results_combined.empty:
        plt.figure(figsize=(4.5, 2.5))  # Slightly reduce width for compactness
        
        sns.stripplot(
            x='Cell type', 
            y='logfoldchanges', 
            data=de_results_combined, 
            hue='Cell type', 
            order=cell_type_order,  # Use the specified order
            palette=cell_type_colors, 
            dodge=0.5,  # Reduced dodge to bring dots closer together
            jitter=0.7,  # Adjusted jitter to slightly reduce spread
            size=2,  # Dot size
            alpha=0.7
        )

        # Prepare for labeling top 3 upregulated and downregulated genes per cell type
        texts = []
        for cell_type in cell_type_order:
            if cell_type == 'Plasma Cells':  # Skip labeling for 'Plasma Cells'
                continue
            # Select the top 3 upregulated and downregulated genes for the current cell type
            cell_type_genes = de_results_combined[de_results_combined['Cell type'] == cell_type]
            top_upregulated = cell_type_genes[cell_type_genes['Regulation'] == 'upregulated'].nlargest(3, 'logfoldchanges')
            top_downregulated = cell_type_genes[cell_type_genes['Regulation'] == 'downregulated'].nsmallest(3, 'logfoldchanges')
            
            # Label the top 3 up/downregulated genes
            top_genes_to_label = pd.concat([top_upregulated, top_downregulated])
            for _, row in top_genes_to_label.iterrows():
                texts.append(plt.text(
                    row['Cell type'], row['logfoldchanges'], 
                    row['names'], fontsize=4.5, ha='right'
                ))

        # Adjust the labels to avoid overlap
        adjust_text(texts)

        # Customize plot
        plt.axhline(y=0, color='black', linestyle='--', linewidth=1)  # Zero line for reference
        plt.title(f'DGE Violin Dot Plot: {condition2} vs {condition1}')
        plt.ylabel('Log Fold Change')
        plt.xlabel('')
        plt.legend(title='')
        plt.gca().set_xticklabels([])
        plt.xticks([])  # Rotate x labels for better readability
        plt.tight_layout()
        plt.grid(False)
        plt.tick_params(axis='y', which='both', left=True, right=False, length=3, color='black')
        # Save the plot
        filename_pdf = f"Final_Notebooks/Figures/Drug_comparison/DGE_violin_dotplot_labeled_per_cell_type_{condition2.replace(' ', '_')}_vs_{condition1.replace(' ', '_')}.pdf"
        plt.savefig(filename_pdf, dpi=300, bbox_inches='tight')
        
        plt.show()

condition_pairs = [
    ('PHA', 'Control'), 
    ('PHA + BTP2', 'PHA'), 
    ('PHA + CM4620', 'PHA'), 
]

# Loop through each condition pair and run the function
for condition1, condition2 in condition_pairs:
    violin_dotplot_dge_labeled_per_cell_type(adata, condition1, condition2)
# Out:
# ranking genes
# /home/as3562/miniconda3/envs/PBMC_env/lib/python3.9/site-packages/anndata/_core/anndata.py:1145: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/as3562/miniconda3/envs/PBMC_env/lib/python3.9/site-packages/anndata/_core/anndata.py:1145: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/as3562/miniconda3/envs/PBMC_env/lib/python3.9/site-packages/anndata/_core/anndata.py:1145: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/as3562/miniconda3/envs/PBMC_env/lib/python3.9/site-packages/anndata/_core/anndata.py:1145: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
# ...

# %%
cell_counts = adata.obs.groupby(['Condition', 'Broad_Manual_Anno_renamed']).size().unstack(fill_value=0)

# Display the cell counts for each condition and cell type
print(cell_counts)
# Out:
# Broad_Manual_Anno_renamed  B Cells  CD14+ Monocytes  CD16+ Monocytes  \
# Condition
# Control                       2332             4086              438
# BTP2                          2143             3665              449
# CM4620                        2334             4282              487
# PHA                           1797             2704              212
# PHA + BTP2                    1599             4421              340
# PHA + CM4620                  1684             4049              441
#
# Broad_Manual_Anno_renamed  Dendritic Cells  NK Cells  CD8+ Effector T Cells  \
# Condition
# Control                                162      2502                   3010
# BTP2                                   112      2220                   2324
# CM4620                                 169      2236                   2727
# PHA                                    234      2136                   2197
# PHA + BTP2                             193      2208                   2592
# ...

# %%
#Create heatmaps of the two similarity metrics (Cosine similarity and Euclidean distance)
sns.set(style="white")
sc.set_figure_params(fontsize=6)

def calculate_centroids(adata, cluster_column, condition_column, condition):
    subset = adata[adata.obs[condition_column] == condition]
    centroids = subset.obs.groupby(cluster_column).apply(lambda x: np.mean(subset[x.index].X, axis=0))
    return np.array(centroids.tolist())

def analyze_conditions(adata, conditions, cluster_column='Broad_Manual_Anno_renamed', condition_column='Condition'):
    condition1, condition2 = conditions
    
    centroids_condition1 = calculate_centroids(adata, cluster_column, condition_column, condition1)
    centroids_condition2 = calculate_centroids(adata, cluster_column, condition_column, condition2)

    cell_types = adata.obs[cluster_column].unique()
    euclidean_distances = [euclidean(centroids_condition1[i], centroids_condition2[i]) for i in range(len(cell_types))]
    cosine_similarities = [cosine_similarity([centroids_condition1[i]], [centroids_condition2[i]])[0][0] for i in range(len(cell_types))]

    return cell_types, euclidean_distances, cosine_similarities

condition_pairs = [
    ('BTP2', 'Control'), 
    ('CM4620', 'Control'), 
    ('BTP2', 'CM4620'), 
    ('PHA', 'Control'), 
    ('PHA + BTP2', 'Control'), 
    ('PHA + CM4620', 'Control'), 
    ('PHA + BTP2', 'PHA'), 
    ('PHA + CM4620', 'PHA'), 
    ('PHA + BTP2', 'PHA + CM4620'),
    # Add more pairs as needed
]

all_results = []
for conditions in condition_pairs:
    cell_types, euclidean_distances, cosine_similarities = analyze_conditions(adata, conditions)
    all_results.append((conditions, cell_types, euclidean_distances, cosine_similarities))

cosine_matrix = pd.DataFrame(index=cell_types)
euclidean_matrix = pd.DataFrame(index=cell_types)
for conditions, cell_types, euclidean_distances, cosine_similarities in all_results:
    comparison = f'{conditions[0]} vs {conditions[1]}'
    cosine_matrix[comparison] = cosine_similarities
    euclidean_matrix[comparison] = euclidean_distances

cosine_matrix = cosine_matrix.T
euclidean_matrix = euclidean_matrix.T

# Remove Plasma Cells from the ordered_cell_types list
ordered_cell_types = ['CD4+ T Cells','CD4+ Treg Cells', 'CD8+ Effector T Cells', 'CD8+ Naive T Cells', 
                      'NK Cells', 'B Cells', 'CD14+ Monocytes', 'CD16+ Monocytes', 'Dendritic Cells']

# Filter out Plasma Cells from cosine and euclidean matrices
cosine_matrix = cosine_matrix[ordered_cell_types]
euclidean_matrix = euclidean_matrix[ordered_cell_types]

# Plot Cosine Similarity Heatmap without Plasma Cells
plt.figure(figsize=(3.5, 2.5))
sns.heatmap(cosine_matrix, annot=False, cmap='magma', cbar_kws={'label': 'Cosine Similarity'}, 
            linecolor='black', linewidths=0.1, xticklabels=ordered_cell_types, vmax=1, vmin=0.3)
plt.xlabel('Cell Type')
plt.ylabel('Condition Comparison')
plt.title('Cosine Similarities between Conditions')
plt.xticks(rotation=45, ha='right')
plt.tick_params(axis='x', which='both', bottom=True, top=False, length=3, color='black')
plt.tick_params(axis='y', which='both', left=True, right=False, length=3, color='black')
plt.tight_layout()
plt.savefig('Final_Notebooks/Figures/Drug_comparison/Cosine_Heatmap_No_Plasma.pdf', bbox_inches='tight', dpi=300)
plt.show()

# Plot Euclidean Distance Heatmap without Plasma Cells
plt.figure(figsize=(3.5, 2.5))
sns.heatmap(euclidean_matrix, annot=False, cmap='magma_r', cbar_kws={'label': 'Euclidean Distance'}, 
            linecolor='black', linewidths=0.1, xticklabels=ordered_cell_types, vmax=25, vmin=5)
plt.xlabel('Cell Type')
plt.ylabel('Condition Comparison')
plt.title('Euclidean Distances between Conditions')
plt.xticks(rotation=45, ha='right')
plt.tick_params(axis='x', which='both', bottom=True, top=False, length=3, color='black')
plt.tick_params(axis='y', which='both', left=True, right=False, length=3, color='black')
plt.tight_layout()
plt.savefig('Final_Notebooks/Figures/Drug_comparison/Euclidean_Heatmap_No_Plasma.pdf', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_3871358/702851825.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   centroids = subset.obs.groupby(cluster_column).apply(lambda x: np.mean(subset[x.index].X, axis=0))
# /tmp/ipykernel_3871358/702851825.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   centroids = subset.obs.groupby(cluster_column).apply(lambda x: np.mean(subset[x.index].X, axis=0))
# ...

# %%
#Create a custom correlation heatmap for the data grouped by celltype and condition
from scipy.cluster.hierarchy import linkage
from matplotlib.colors import ListedColormap
sc.set_figure_params(fontsize=12)

adata.obs['Celltype_Condition'] = adata.obs['Broad_Manual_Anno_renamed'].astype(str) + '_' + adata.obs['Condition'].astype(str)

adata.obs['Condition_Color'] = adata.obs['Condition'].astype(str)
adata.obs['Celltype_Color'] = adata.obs['Broad_Manual_Anno_renamed'].astype(str)

mean_expression = adata.to_df().groupby(adata.obs['Celltype_Condition']).mean()

correlation_matrix = mean_expression.T.corr()

Z = linkage(correlation_matrix, method='average', metric='correlation')

celltype_colors = {
    'B Cells': '#8DD3C7',
    'CD14+ Monocytes': '#74C476',
    'CD16+ Monocytes': '#BEBADA',
    'Dendritic Cells': '#FB8072',
    'CD8+ Effector T Cells': '#80B1D3',
    'CD8+ Naive T Cells': '#FDB462',
    'CD4+ T Cells': '#B3DE69',
    'NK Cells': '#FCCDE5',
    'Plasma Cells': '#AE017E',
    'CD4+ Treg Cells': '#BC80BD'
}
condition_palette ={
'Control':'#E78AC3',
'BTP2':'#FFD92F',
'CM4620':'#377EB8',
'PHA':'#7570B3',
'PHA + BTP2':'#E41A1C',
'PHA + CM4620':'#4DAF4A'}

condition_colors = condition_palette

row_colors = adata.obs[['Condition','Celltype_Condition', 'Broad_Manual_Anno_renamed']].drop_duplicates().set_index('Celltype_Condition')
row_colors['Condition'] = row_colors['Condition'].astype(str).map(condition_colors)
row_colors['Broad_Manual_Anno_renamed'] = row_colors['Broad_Manual_Anno_renamed'].astype(str).map(celltype_colors)

row_colors = row_colors.rename(columns={'Broad_Manual_Anno_renamed': 'Cell Type'})

row_colors = row_colors[['Cell Type','Condition']]

g = sns.clustermap(correlation_matrix.T, 
                   row_linkage=Z,
                   col_linkage=Z,
                   col_colors=row_colors,
                   cmap="coolwarm",
                   #center=0.8,
                   figsize=(10, 9.3),
                   linewidths=0,
                   linecolor='black',
                    dendrogram_ratio=(0.00001, 0.0001), row_cluster=True,col_cluster=True,
                   cbar_pos=(0.8, 0.5, 0.02, 0.07),vmin=-1,vmax=1)  

g.ax_heatmap.set_xticklabels([])
g.ax_heatmap.set_yticklabels([])
g.ax_heatmap.set_xlabel('')
g.ax_heatmap.set_ylabel('')
g.ax_heatmap.tick_params(right=False, bottom=False)
g.ax_heatmap.grid(False)
g.ax_col_colors.grid(False)

celltype_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=label) for label, color in celltype_colors.items()]
condition_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=label) for label, color in condition_colors.items()]

g.ax_heatmap.legend(handles=celltype_handles + condition_handles, loc='center left', bbox_to_anchor=(1, 0.50), ncol=1, title="",frameon=False)

plt.title('Correlation')
plt.savefig('Final_Notebooks/Figures/Drug_comparison/Heatmap.pdf', bbox_inches='tight',dpi=300)
plt.show()

# %%
#Compare Technical replicates by calculating the correlation between pairs
sc.set_figure_params(fontsize=12)

# Loop through each donor and generate correlation matrix plots
for donor in adata.obs['Donor'].unique():
    # Select the data for the current donor's replicates
    donor_data = adata[adata.obs['Donor'] == donor].copy()
    donor_data.obs['Rep_ID'] = donor_data.obs['Rep_ID'].astype('category')
    
    sc.tl.dendrogram(donor_data, groupby='Rep_ID', linkage_method='weighted')
    # Generate the correlation matrix plot
    sc.pl.correlation_matrix(donor_data,
                             groupby='Rep_ID', 
                             show=False,  # Do not display the plot
                             show_correlation_numbers=False,
                             cmap='BuPu',
                             dendrogram=True,
                             figsize=(6, 4), 
                             vmin=0.9)
    plt.tick_params(axis='x', which='both', bottom=True, top=True, length=3, color='black')
    plt.tick_params(axis='y', which='both', left=True, right=True, length=3, color='black')
    # Save the plot
    plt.savefig(f'Final_Notebooks/Figures/Tech_rep/correlation_matrix_{donor}.pdf',bbox_inches='tight')
    plt.close()  # Close the figure to avoid memory issues
# Out:
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_Rep_ID']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_Rep_ID']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_Rep_ID']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_Rep_ID']`

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# adjustText                1.3.0
# anndata                   0.10.9
# anyio                     4.6.2.post1
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# array_api_compat          1.9.1
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     24.2.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# Brotli                    1.1.0
# cached-property           1.5.2
# certifi                   2024.8.30
# cffi                      1.17.1
# charset-normalizer        3.4.0
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.3.0
# cycler                    0.12.1
# debugpy                   1.8.8
# decorator                 5.1.1
# defusedxml                0.7.1
# entrypoints               0.4
# ...
